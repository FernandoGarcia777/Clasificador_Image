# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoGarcia777/Clasificador_Image/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clonar tu repositorio (cambia TU_USUARIO y TU_REPO)
# !git clone https://github.com/FernandoGarcia777/Clasificador_Image.git

# 2. Entrar a la carpeta
# %cd Clasificador_Image

# 3. Instalar las dependencias
# !pip install -r requirements.txt

# 4. Ejecutar la app
# !python app_mnist.py
